# %% [markdown]
# # Project 1: Analysis on SAT and ACT Participation and Performance in U.S.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The ACT has long claimed the title as the most widely used college admission assessment in United States since 2012 [[Source: Washington Post, 2018]](https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/). Many states have enacted law to mandate ACT as the default assessment for high school graduates, giving rise to the popularity of ACT, taking over SAT. Thus for the College Board, it would be quintessential to understand the reason behind ACT long-lasting popularity and formulate a cost-efficient solution to improve the SAT participation rate.

# %% [markdown]
# ## Executive Summary
#
# In March 2016, a new format of Standardized Test (SAT) was released by its adminstrative and management body, the College Board. The format changes was aimed to promote higher participation rate in the assessment. David Coleman, president of the College Board, commented that the SAT was seen by the public “narrowly as a test for advanced kids.” [[Source: Washington Post, 2018]](https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/). It was revered for its design emphasis on critical thinking and robust vocabulary, a hallmark that shy away the general public.
#
# Henceforth, the College Board has decided to simplify the assessment design — from the original 10 sections down to 5 [[Source: College Board, n.d.]](https://collegereadiness.collegeboard.org/sat/inside-the-test/compare-old-new-specifications). Every component of the SAT, including the essay, has a new format and a shift in the skills it focuses on, in the hope of encouranging influx of participants from its rival, American College Testing (ACT).
#
# In this project, we will dive into the SAT and ACT data in the year 2017 and 2018, which detailed state-wide average participation rate and the assessments' corresponding subject scores to unravel any statistical relationship between the variables. The relationship and distribution are visualized to reveal patterns that could show details that would otherwise stayed unseen.
#
# Upon understanding the statistical relationship, we will then zoom into some states to understand the effect of policy changes that has affected the participation rate or public sentiments towards the SAT. From which, we would devise the proven, most cost-effective recommendation to improve the participation rate of SAT in the United States.
#
# The data were sourced from statistics available online, which were then converted into table (csv) format for the ease of data transformation and analysis. The sources are as followed:
#
# 1. [SAT 2017](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# 2. [ACT 2017](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)
# 3. [SAT 2018](https://reports.collegeboard.org/sat-suite-program-results/state-results)
# 4. [ACT 2018](http://www.act.org/content/dam/act/unsecured/documents/cccr2018/Average-Scores-by-State.pdf)

# %% [markdown]
# ### Contents:
# - [2017 Data Import & Cleaning](#2017-Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2017.describe(include='all')
# Out:
#           State Participation  Evidence-Based Reading and Writing        Math  \
# count        51            51                           51.000000   51.000000
# unique       51            34                                 NaN         NaN
# top     Vermont            3%                                 NaN         NaN
# freq          1             8                                 NaN         NaN
# mean        NaN           NaN                          569.117647  547.627451
# std         NaN           NaN                           45.666901   84.909119
# min         NaN           NaN                          482.000000   52.000000
# 25%         NaN           NaN                          533.500000  522.000000
# 50%         NaN           NaN                          559.000000  548.000000
# 75%         NaN           NaN                          613.000000  599.000000
# max         NaN           NaN                          644.000000  651.000000
#
#               Total
# ...

# %% [markdown]
# SAT system consist of 2 tests, each test score range from 200 to 800. But from the stats of sat_2017, the minimum of **'Math'** column is only **200**. There is certainly an error in the dataset. But let's check how many rows are having this error.

# %%
sat_2017[sat_2017['Math']<200]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %% [markdown]
# It appears **'Maryland'** is the only row that has the issue. We will discuss in later part on how to handle this error. For now, we would just keep it noted.

# %%
act_2017.describe(include='all')
# Out:
#           State Participation    English       Math    Reading    Science  \
# count        52            52  52.000000  52.000000  52.000000  52.000000
# unique       52            28        NaN        NaN        NaN        NaN
# top     Vermont          100%        NaN        NaN        NaN        NaN
# freq          1            17        NaN        NaN        NaN        NaN
# mean        NaN           NaN  20.919231  21.173077  22.001923  21.040385
# std         NaN           NaN   2.332132   1.963602   2.048672   3.151113
# min         NaN           NaN  16.300000  18.000000  18.100000   2.300000
# 25%         NaN           NaN  19.000000  19.400000  20.475000  19.900000
# 50%         NaN           NaN  20.550000  20.900000  21.700000  21.150000
# 75%         NaN           NaN  23.300000  23.100000  24.125000  22.525000
# max         NaN           NaN  25.500000  25.300000  26.000000  24.900000
#
#        Composite
# count         52
# unique        38
# top         20.3
# ...

# %% [markdown]
# From the stats above, it seems that **'Science'** score has at least one outlier among the data, which has a score of **2.3** (significantly lower than the lower quartile). ACT score system range from **1 to 36**, however it is impossible that a state-average would score only at **2.3**. Let's dig in to see which state is having this issue.

# %% [markdown]
# From the stats table of act_2017, there seems to be no value for the numerical statistics of **'Composite'** and **'Participation'** field. It might be caused by wrong datatype recognized for the 'Composite' column. Let's take a look at the unique value of the column to identify if we have any error value.

# %%
act_2017[act_2017['Science']<15]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %% [markdown]
# Well. It seems like it is **Maryland** that has the issue of typo again. We may use the composite score to recalculate the actual **'Science'** score.

# %%
act_2017['Composite'].unique()
# Out:
# array(['21.0', '19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2',
#        '24.1', '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7',
#        '20.0', '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4',
#        '20.3', '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7',
#        '24.0', '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %% [markdown]
# The participation column in both SAT and ACT data are not in numerical format because of the 'percent' (%) symbol in the text. There would be a need to convert these columns into numerical for futher analysis.

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: The SAT and ACT datasets describe the statistics of all 50 states in the United States and Washington DC. The statisics includes participation rate and scores of their respective scope of examination of each of the 50 states and DC.
#
# SAT only have examination on English (Reading & Writing) and Mathematics skills. While ACT takes into account of some other skills, which includes Science and English skill is broken down into Reading and Writing as 2 different tests.
#
# There is an additional row in the ACT dataset, which is the National Average of each data field. The row is unnecessary as we may always calculate the national average by other means.
#
# From the checking above, it shows that there are some error in the dataset that needs to be addressed or remedied, such as Typo and Wrong Datatype.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: There is no missing value in both datasets, so that's a good start. Each of the datasets comprises of all 50 states in the United States and Washington DC, which seems to complete. However, as stated above, the 'National' average row in the ACT dataset will be removed for further analysis.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# 1. In SAT_2017, Maryland has an average math score of less than 200, at 52. It is perhaps a typo from the actual 520. But there is no certainty until we find out the actual score. Or for a quick remedy, we may replace it with the mean of math score. But for this case, we may actually reverse-calculate the math score from the total score.
#
#
# 2. Composite score in ACT_2017 data has a string of '20.2x', which is not numerical. It is most likely a typo, we can check by summing up the 4 tests score and get the average. Then we will replace the value with the actual value and cast the column as float.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
sat_2017.loc[sat_2017['Math']<200, 'Math']
# Out:
# 20    52
# Name: Math, dtype: int64

# %%
sat_2017.loc[sat_2017['Math']<200, 'Total']
# Out:
# 20    1060
# Name: Total, dtype: int64

# %%
sat_2017.loc[sat_2017['Math']<200, 'Math'] = sat_2017.loc[sat_2017['Math']<200, 'Total'] - sat_2017.loc[sat_2017['Math']<200, 'Evidence-Based Reading and Writing']
sat_2017.loc[sat_2017['Math']<200, 'Math']
# Out:
# Series([], Name: Math, dtype: int64)

# %% [markdown]
# The typo error in SAT dataset on **Maryland** is corrected. There is no longer any row with **Math** score lower than 200.

# %%
sat_2017[sat_2017.State=='Maryland']
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
act_2017.loc[act_2017.Science < 10,'Science'] = 4*float(act_2017.loc[act_2017.Science < 10, 'Composite']) - act_2017.loc[act_2017.Science < 10, ['English','Math','Reading']].sum(axis=1)

# %%
act_2017.loc[act_2017.Science < 10]
# Out:
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []

# %%
act_2017[act_2017.State=='Maryland']
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.8      23.6

# %% [markdown]
# The typo error in ACT dataset on **Maryland** is corrected. There is no longer any row with **Math** score lower than 10. We will double check again with the descriptive statistics of both datasets to confirm there is no suspicious outliers to be addressed.

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.453846
# std     2.332132   1.963602   2.048672   1.737303
# min    16.300000  18.000000  18.100000  18.200000
# 25%    19.000000  19.400000  20.475000  19.975000
# 50%    20.550000  20.900000  21.700000  21.300000
# 75%    23.300000  23.100000  24.125000  23.200000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  556.882353  1126.098039
# std                             45.666901   47.121395    92.494812
# min                            482.000000  468.000000   950.000000
# 25%                            533.500000  523.500000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# Both the datasets looks good right now. However, we may notice that **Composite** datafield in the ACT dataset is not showing up on the describe() function.
# The **Participation** field are also not showing up for both the dataframe.
# Maybe there is some error in the data that cause it to be non-numerical. Let's check on the datatype.

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: As suspected, the **Participation** field in both dataset and **Composite** score in ACT datasets are not in the correct datatype. We need to find out the source of the issue and fix the problem.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# SAT Participation
sat_2017['Participation'] = sat_2017['Participation'].apply(lambda row: int(row.replace('%','')))

# %%
sat_2017.dtypes['Participation']
# Out:
# dtype('int64')

# %%
# ACT Participation
act_2017['Participation'] = act_2017['Participation'].apply(lambda row: int(row.replace('%','')))

# %%
act_2017.dtypes['Participation']
# Out:
# dtype('int64')

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Composite field in ACT
act_2017.Composite.unique()
# Out:
# array(['21.0', '19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2',
#        '24.1', '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7',
#        '20.0', '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4',
#        '20.3', '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7',
#        '24.0', '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %%
# ACT Composite
act_2017['Composite'] = act_2017['Composite'].apply(lambda row: float(row.replace('x','')))

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act_2017.dtypes['Composite']
# Out:
# dtype('float64')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
# Shorten the long column name in SAT dataset
sat_2017.columns = sat_2017.columns.str.replace('Evidence-Based Reading and Writing', 'Reading Writing')

# %%
# Replace all current columns with lowercase and space with underscore
sat_2017.columns = sat_2017.columns.map(lambda col: col.lower().replace(' ', '_'))

# Add-on prefixes and subfixes in case of data merging in the later part
sat_2017.columns = sat_2017.columns[1:].map(lambda col: 'sat_' + col + '_2017').insert(0, sat_2017.columns[0])

# %%
sat_2017.columns
# Out:
# Index(['state', 'sat_participation_2017', 'sat_reading_writing_2017',
#        'sat_math_2017', 'sat_total_2017'],
#       dtype='object')

# %%
# Replace all current columns with lowercase and space with underscore
act_2017.columns = act_2017.columns.str.lower()

# Add-on prefixes and subfixes in case of data merging in the later part
act_2017.columns = act_2017.columns[1:].map(lambda col: 'act_' + col + '_2017').insert(0, act_2017.columns[0])

# %%
act_2017.columns
# Out:
# Index(['state', 'act_participation_2017', 'act_english_2017', 'act_math_2017',
#        'act_reading_2017', 'act_science_2017', 'act_composite_2017'],
#       dtype='object')

# %% [markdown]
# All the column names in both datasets have been standardized.

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|_object_|SAT 2017|All 50 states in the U.S. and Washington D.C.|
# |**sat_participation_2017**|_integer_|SAT 2017|Student participation rate for SAT in each states in 2017 (units percent to zero decimal places 98 means 98%)|
# |**sat_reading_writing_2017**|_integer_|SAT 2017|State-average evidence-based reading and writing score in 2017 (units score range from 200 to 800)|
# |**sat_math_2017**|_integer_|SAT 2017|State-average mathematics score in 2017 (units score range from 200 to 800)|
# |**sat_total_2017**|_integer_|SAT 2017|State-average total score in 2017 (units score range from 400 to 1600)|
# |**state**|_object_|ACT 2017|All 50 states in the U.S. and Washington D.C.|
# |**act_participation_2017**|_integer_|ACT 2017|Student participation rate for ACT in each states in 2017 (units percent to zero decimal places 98 means 98%)|
# |**act_english_2017**|_float_|ACT 2017|State-average evidence-based reading and writing score in 2017 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_math_2017**|_float_|ACT 2017|State-average mathematics score in 2017 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_reading_2017**|_float_|ACT 2017|State-average reading score in 2017 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_science_2017**|_float_|ACT 2017|State-average mathematics score in 2017 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_composite_2017**|_float_|ACT 2017|State-average composite score in 2017 (units score to one decimal places range from 1.0 to 36.0)|
# |**state**|_object_|SAT 2018|All 50 states in the U.S. and Washington D.C.|
# |**sat_participation_2018**|_integer_|SAT 2018|Student participation rate for SAT in each states in 2018 (units percent to zero decimal places 98 means 98%)|
# |**sat_reading_writing_2018**|_integer_|SAT 2018|State-average evidence-based reading and writing score in 2018 (units score range from 200 to 800)|
# |**sat_math_2018**|_integer_|SAT 2018|State-average mathematics score in 2018 (units score range from 200 to 800)|
# |**sat_total_2018**|_integer_|SAT 2018|State-average total score in 2018 (units score range from 400 to 1600)|
# |**state**|_object_|ACT 2018|All 50 states in the U.S. and Washington D.C.|
# |**act_participation_2018**|_integer_|ACT 2018|Student participation rate for ACT in each states in 2018 (units percent to zero decimal places 98 means 98%)|
# |**act_english_2018**|_float_|ACT 2018|State-average evidence-based reading and writing score in 2018 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_math_2018**|_float_|ACT 2018|State-average mathematics score in 2018 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_reading_2018**|_float_|ACT 2018|State-average reading score in 2018 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_science_2018**|_float_|ACT 2018|State-average mathematics score in 2018 (units score to one decimal places range from 1.0 to 36.0)|
# |**act_composite_2018**|_float_|ACT 2018|State-average composite score in 2018 (units score to one decimal places range from 1.0 to 36.0)|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# Dropping the national row
act_2017 = act_2017.drop(0).reset_index().drop('index', axis=1)
act_2017.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                     100              18.9           18.4
# 1      Alaska                      65              18.7           19.8
# 2     Arizona                      62              18.6           19.8
# 3    Arkansas                     100              18.9           19.0
# 4  California                      31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# Merging all 2017 dataset
combined_2017 = pd.merge(sat_2017, act_2017, on='state')

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
# Exporting code to csv
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# Importing data for 2018
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018_updated.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2018.describe(include='all')
# Out:
#           State Participation  Evidence-Based Reading and Writing        Math  \
# count        51            51                           51.000000   51.000000
# unique       51            33                                 NaN         NaN
# top     Vermont            3%                                 NaN         NaN
# freq          1             6                                 NaN         NaN
# mean        NaN           NaN                          563.686275  556.235294
# std         NaN           NaN                           47.502627   47.772623
# min         NaN           NaN                          480.000000  480.000000
# 25%         NaN           NaN                          534.500000  522.500000
# 50%         NaN           NaN                          552.000000  544.000000
# 75%         NaN           NaN                          610.500000  593.500000
# max         NaN           NaN                          643.000000  655.000000
#
#               Total
# ...

# %% [markdown]
# It seems that the data cleaning procedure that we have done above for the 2017 dataset needs to be repeated for the 2018 one to convert each column to the correct datatype.

# %%
sat_2018['Participation'] = sat_2018['Participation'].apply(lambda row: int(row.replace('%','')))

# %%
sat_2018.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2018.columns = sat_2018.columns.str.replace('Evidence-Based Reading and Writing', 'Reading Writing')
sat_2018.columns = sat_2018.columns.map(lambda col: col.lower().replace(' ','_'))
sat_2018.columns = sat_2018.columns[1:].map(lambda col: 'sat_' + col + '_2018').insert(0, sat_2018.columns[0])

# %%
sat_2018.head()
# Out:
#         state  sat_participation_2018  sat_reading_writing_2018  \
# 0     Alabama                       6                       595
# 1      Alaska                      43                       562
# 2     Arizona                      29                       577
# 3    Arkansas                       5                       592
# 4  California                      60                       540
#
#    sat_math_2018  sat_total_2018
# 0            571            1166
# 1            544            1106
# 2            572            1149
# 3            576            1169
# 4            536            1076

# %%
act_2018.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
act_2018.describe(include='all')
# Out:
#           State  Percentage of Students Tested  Average Composite Score  \
# count        51                      51.000000                51.000000
# unique       51                            NaN                      NaN
# top     Vermont                            NaN                      NaN
# freq          1                            NaN                      NaN
# mean        NaN                      61.647059                21.486275
# std         NaN                      34.080976                 2.106278
# min         NaN                       7.000000                17.700000
# 25%         NaN                      28.500000                19.950000
# 50%         NaN                      66.000000                21.300000
# 75%         NaN                     100.000000                23.550000
# max         NaN                     100.000000                25.600000
#
#         Average English Score  Average Math Score  Average Reading Score  \
# ...

# %%
# Direct renaming using dictionary and rename function to match with the 2017 dataset
act_2018.rename(columns={'State':'state',
                         'Percentage of Students Tested':'participation',
                         'Average Composite Score':'composite',
                         'Average English Score':'english',
                         'Average Math Score':'math',
                         'Average Reading Score':'reading',
                         'Average Science Score':'science'
                        }, inplace=True)

# %%
act_2018.dtypes
# Out:
# state             object
# participation      int64
# composite        float64
# english          float64
# math             float64
# reading          float64
# science          float64
# dtype: object

# %%
act_2018.columns = act_2018.columns.map(lambda col: col.lower())
act_2018.columns = act_2018.columns[1:].map(lambda col: 'act_' + col + '_2018').insert(0, act_2018.columns[0])

# %%
act_2018.head()
# Out:
#         state  act_participation_2018  act_composite_2018  act_english_2018  \
# 0     Alabama                     100                19.1              18.9
# 1      Alaska                      33                20.8              19.8
# 2     Arizona                      66                19.2              18.2
# 3    Arkansas                     100                19.4              19.1
# 4  California                      27                22.7              22.5
#
#    act_math_2018  act_reading_2018  act_science_2018
# 0           18.3              19.6              19.0
# 1           20.6              21.6              20.7
# 2           19.4              19.5              19.2
# 3           18.9              19.7              19.4
# 4           22.5              23.0              22.1

# %%
# Merging data for 2018 datasets
combined_2018 = pd.merge(sat_2018, act_2018, on='state')

# Merging all data from 2017 and 2018 datasets
final = pd.merge(combined_2017, combined_2018, on='state')

# %%
combined_2018.columns
# Out:
# Index(['state', 'sat_participation_2018', 'sat_reading_writing_2018',
#        'sat_math_2018', 'sat_total_2018', 'act_participation_2018',
#        'act_composite_2018', 'act_english_2018', 'act_math_2018',
#        'act_reading_2018', 'act_science_2018'],
#       dtype='object')

# %%
final.columns
# Out:
# Index(['state', 'sat_participation_2017', 'sat_reading_writing_2017',
#        'sat_math_2017', 'sat_total_2017', 'act_participation_2017',
#        'act_english_2017', 'act_math_2017', 'act_reading_2017',
#        'act_science_2017', 'act_composite_2017', 'sat_participation_2018',
#        'sat_reading_writing_2018', 'sat_math_2018', 'sat_total_2018',
#        'act_participation_2018', 'act_composite_2018', 'act_english_2018',
#        'act_math_2018', 'act_reading_2018', 'act_science_2018'],
#       dtype='object')

# %%
# Sanity-check: final checking on whether there is any missing data or error
final.isnull().sum()
# Out:
# state                       0
# sat_participation_2017      0
# sat_reading_writing_2017    0
# sat_math_2017               0
# sat_total_2017              0
# act_participation_2017      0
# act_english_2017            0
# act_math_2017               0
# act_reading_2017            0
# act_science_2017            0
# act_composite_2017          0
# sat_participation_2018      0
# sat_reading_writing_2018    0
# sat_math_2018               0
# sat_total_2018              0
# act_participation_2018      0
# act_composite_2018          0
# act_english_2018            0
# act_math_2018               0
# act_reading_2018            0
# act_science_2018            0
# dtype: int64

# %%
# Exporting to the final & complete csv
final.to_csv("../data/final.csv")

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# Quick sanity check on all the data descriptive statistics
final.describe().T
# Out:
#                           count         mean        std    min      25%  \
# sat_participation_2017     51.0    39.803922  35.276632    2.0     4.00
# sat_reading_writing_2017   51.0   569.117647  45.666901  482.0   533.50
# sat_math_2017              51.0   556.882353  47.121395  468.0   523.50
# sat_total_2017             51.0  1126.098039  92.494812  950.0  1055.50
# act_participation_2017     51.0    65.254902  32.140842    8.0    31.00
# act_english_2017           51.0    20.931373   2.353677   16.3    19.00
# act_math_2017              51.0    21.182353   1.981989   18.0    19.40
# act_reading_2017           51.0    22.013725   2.067271   18.1    20.45
# act_science_2017           51.0    21.462745   1.753392   18.2    19.95
# act_composite_2017         51.0    21.519608   2.020695   17.8    19.80
# sat_participation_2018     51.0    45.745098  37.314256    2.0     4.50
# sat_reading_writing_2018   51.0   563.686275  47.502627  480.0   534.50
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
# Function to calculate standard deviation

def std(col):
    mean = final[col].mean()
    return (sum([(value - mean)**2 for value in final[col]])/len(final))**0.5

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# Output-ing std for each column
{col: std(col) for col in final._get_numeric_data().columns}
# Out:
# {'sat_participation_2017': 34.92907076664508,
#  'sat_reading_writing_2017': 45.21697020437866,
#  'sat_math_2017': 46.65713364485503,
#  'sat_total_2017': 91.58351056778743,
#  'act_participation_2017': 31.824175751231806,
#  'act_english_2017': 2.3304876369363363,
#  'act_math_2017': 1.9624620273436781,
#  'act_reading_2017': 2.0469029314842646,
#  'act_science_2017': 1.7361170088327353,
#  'act_composite_2017': 2.000786081581989,
#  'sat_participation_2018': 36.946619223539415,
#  'sat_reading_writing_2018': 47.03460978357609,
#  'sat_math_2018': 47.30194550378352,
#  'sat_total_2018': 93.22742384464433,
#  'act_participation_2018': 33.745194881997506,
#  'act_composite_2018': 2.0855261815801147,
#  'act_english_2018': 2.4222536143202795,
#  'act_math_2018': 2.015707255555717,
#  'act_reading_2018': 2.145891884510421,
#  'act_science_2018': 1.8516885484833543}

# %%
np.std(final)
# Out:
# sat_participation_2017      34.929071
# sat_reading_writing_2017    45.216970
# sat_math_2017               46.657134
# sat_total_2017              91.583511
# act_participation_2017      31.824176
# act_english_2017             2.330488
# act_math_2017                1.962462
# act_reading_2017             2.046903
# act_science_2017             1.736117
# act_composite_2017           2.000786
# sat_participation_2018      36.946619
# sat_reading_writing_2018    47.034610
# sat_math_2018               47.301946
# sat_total_2018              93.227424
# act_participation_2018      33.745195
# act_composite_2018           2.085526
# act_english_2018             2.422254
# act_math_2018                2.015707
# act_reading_2018             2.145892
# act_science_2018             1.851689
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: The standard deviation from both the methods are exactly the same. Numpy.std method is calculating for population standard deviation by default, which is the same as the formula above that we used to construct our function.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### SAT Participation

# %%
final.sort_values('sat_participation_2017', ascending=False)[['state','sat_participation_2017']].head(1)
# Out:
#                   state  sat_participation_2017
# 8  District of Columbia                     100

# %%
final.sort_values('sat_participation_2017', ascending=True)[['state','sat_participation_2017']].head(1)
# Out:
#            state  sat_participation_2017
# 34  North Dakota                       2

# %% [markdown]
# > Washington DC is one of the state/district in the US that has the highest SAT participation in 2017, at 100% full participation. While North Dakota is the lowest, at 2% only.

# %%
final.sort_values('sat_participation_2018', ascending=False)[['state','sat_participation_2018']].head(1)
# Out:
#       state  sat_participation_2018
# 5  Colorado                     100

# %%
final.sort_values('sat_participation_2018', ascending=True)[['state','sat_participation_2018']].head(1)
# Out:
#            state  sat_participation_2018
# 34  North Dakota                       2

# %% [markdown]
# > Colorado has climbed to the top and became one of the state in the US that has the highest SAT participation in 2018, at 100% full participation. While North Dakota is still the lowest, at 2% only with no change from 2017.

# %% [markdown]
# ### ACT Participation

# %%
final.sort_values('act_participation_2017', ascending=False)[['state','act_participation_2017']].head(1)
# Out:
#      state  act_participation_2017
# 0  Alabama                     100

# %%
final.sort_values('act_participation_2017', ascending=True)[['state','act_participation_2017']].head(1)
# Out:
#     state  act_participation_2017
# 19  Maine                       8

# %%
final.sort_values('act_participation_2018', ascending=False)[['state','act_participation_2018']].head(1)
# Out:
#      state  act_participation_2018
# 0  Alabama                     100

# %%
final.sort_values('act_participation_2018', ascending=True)[['state','act_participation_2018']].head(1)
# Out:
#     state  act_participation_2018
# 19  Maine                       7

# %% [markdown]
# > As contrary to the SAT participation, ACT participation rate has almost no change in the top and last place, with minimal change in the rate as well. The top is Alabama and the last is Maine in both 2017 and 2018.

# %% [markdown]
# ### SAT Total Score

# %%
final.sort_values('sat_total_2017', ascending=False)[['state','sat_total_2017']].head(1)
# Out:
#         state  sat_total_2017
# 23  Minnesota            1295

# %%
final.sort_values('sat_total_2018', ascending=False)[['state','sat_total_2018']].head(1)
# Out:
#         state  sat_total_2018
# 23  Minnesota            1298

# %%
final.sort_values('sat_total_2017', ascending=True)[['state','sat_total_2017']].head(1)
# Out:
#                   state  sat_total_2017
# 8  District of Columbia             950

# %%
final.sort_values('sat_total_2018', ascending=True)[['state','sat_total_2018']].head(1)
# Out:
#                   state  sat_total_2018
# 8  District of Columbia             977

# %% [markdown]
# > From the data above, we can see that Minnesota has achieved the highest total score for both 2017 and 2018, close to 1300. While Washington DC has the lowest SAT score for 2 years, this might have something to do with the high participation rate in DC.

# %% [markdown]
# # ACT Composite Score

# %%
final.sort_values('act_composite_2017', ascending=False)[['state','act_composite_2017']].head(1)
# Out:
#             state  act_composite_2017
# 29  New Hampshire                25.5

# %%
final.sort_values('act_composite_2017', ascending=False)[['state','act_composite_2017']].head(1)
# Out:
#             state  act_composite_2017
# 29  New Hampshire                25.5

# %%
final.sort_values('act_composite_2017', ascending=True)[['state','act_composite_2017']].head(1)
# Out:
#      state  act_composite_2017
# 28  Nevada                17.8

# %%
final.sort_values('act_composite_2017', ascending=True)[['state','act_composite_2017']].head(1)
# Out:
#      state  act_composite_2017
# 28  Nevada                17.8

# %% [markdown]
# > Similar to the SAT total score, ACT composite score have the same top scorer state and bottom scorer state for 2017 and 2018. New Hampshire scored the highest at 25.5 for both years while Nevada scored the lowest at 17.8

# %% [markdown]
# ### Change in Participation Rate in 2017 and 2018 for top state

# %%
final.loc[final.sat_participation_2017==100, ['state','sat_participation_2017','sat_participation_2018']]
# Out:
#                    state  sat_participation_2017  sat_participation_2018
# 6            Connecticut                     100                     100
# 7               Delaware                     100                     100
# 8   District of Columbia                     100                      92
# 22              Michigan                     100                     100

# %% [markdown]
# > There are 4 states that has 100% participation in 2017. Out of these 4 states, only Washington DC has a dip in the participation rate in 2018. All the other 3 states are still maintaining at 100% participation rate.

# %%
final.loc[final.act_participation_2017==100, ['state','act_participation_2017','act_participation_2018']]
# Out:
#              state  act_participation_2017  act_participation_2018
# 0          Alabama                     100                     100
# 3         Arkansas                     100                     100
# 5         Colorado                     100                      30
# 17        Kentucky                     100                     100
# 18       Louisiana                     100                     100
# 23       Minnesota                     100                      99
# 24     Mississippi                     100                     100
# 25        Missouri                     100                     100
# 26         Montana                     100                     100
# 28          Nevada                     100                     100
# 33  North Carolina                     100                     100
# 36        Oklahoma                     100                     100
# 40  South Carolina                     100                     100
# ...

# %% [markdown]
# > There are many more states that has 100% participation rate in 2017, it is not hard to speculate that ACT is more popular than SAT in the United States, speaking from the state-level. Most of these states still maintain full (or almost full) participation rate in 2018. However, Colorado has suffered 70% drop in the rate in 1-year time, most likely this is due to some policy change, there is a need to investigate further on this matter to understand the situation

# %% [markdown]
# ### Balanced Participation State

# %%
columns = ['state', 'sat_participation_2017', 'sat_participation_2018', 
           'act_participation_2017', 'act_participation_2018']
final.loc[(final.sat_participation_2017>50) & (final.act_participation_2017>50), columns]
# Out:
#       state  sat_participation_2017  sat_participation_2018  \
# 9   Florida                      83                      56
# 10  Georgia                      61                      70
# 11   Hawaii                      55                      56
#
#     act_participation_2017  act_participation_2018
# 9                       73                      66
# 10                      55                      53
# 11                      90                      89

# %% [markdown]
# > Interestingly, there are 3 states that has more than 50% participation for both SAT and ACT. Florida has the biggest fluctuation in the participation over 1 year, suffer drop in participation for both the test. While for Georgia and Hawaii, the participation rate is relatively stable.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
corr = final.corr().round(2)
f, ax = plt.subplots(figsize=(16, 16))
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, ax=ax, mask=mask, square=True, linewidths=.5, cbar_kws={"shrink": .5}, alpha=.9, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# From the correlation plot above, it is easy to see that there are specific zone where the correlation are extremely high - including negatively high, which indicates negative correlation. The zone can be segregated as such:
#
# 1. All the variable in 2017 display very high correlation with its corresponding 2018 data.
#
# 2. For SAT, the **math** score is highly correlated to the **reading and writing**, which means they are collinear; The higher the math score, the higher the reading and writing score.
#
# 3. Similar pattern as point no. 2 is happening in ACT, whereby all the 4 subjects are highly correlated to each other, rendering all of them to be collinear variables.
#
# 4. The SAT total score is highly correlated to the 2 subjects, which is perfectly sensible because it is calculated as the sum of the individual score.
#
# 5. Same thing goes for ACT composite score, which is the average score of all its 4 subjects.
#
# We may remove all the collinear variable from the correlation heatmap to have a clearer view of the variable correlation. Since all the subjects within each test is collinear to the total or composite score, we may drop the subject row. Apart from that, we may need to observe only 1 year as the year does not affect much on the variable correlation.

# %%
corr = final[['sat_participation_2017','act_participation_2017','sat_total_2017','act_composite_2017']].corr().round(2)
f, ax = plt.subplots(figsize=(8, 8))
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, ax=ax, mask=mask, square=True, linewidths=.5, cbar_kws={"shrink": .5}, alpha=.9, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# After we filter the data down to only 4 variables, it is now clearer that the SAT participation rate is highly correlated to the ACT participation rate (though with a negative relationship). That would mean that most of the states are either extremely inclined to SAT or extremely inclined to ACT.
#
# Apart from that, we may notice that the SAT participation rate have a strong negative correlation to the total score. Thus, with higher participation, the state average score would be lower. The same relationship also exhibited by ACT, where the composite score is negatively correlated to its participation rate.
#
# However, there is relatively low correlation between the SAT total score and the ACT composite score.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(12,12))
    ax = ax.ravel()
    for i, column in enumerate(list_of_columns):
        ax[i].hist(dataframe[column]) 
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylim(0, 20)
        ax[i].set_title(list_of_titles[i], pad=15.0)
        ax[i].axvline(dataframe[column].median(), color='k', ls='--')
        ax[i].annotate('  Median\n  '+str(dataframe[column].median()), (dataframe[column].median(),17.5))
        ax[i].annotate('  LQ\n  '+str(dataframe[column].quantile(0.25)), (dataframe[column].quantile(0.25),17.5))
        ax[i].annotate('  HQ\n  '+str(dataframe[column].quantile(0.75)), (dataframe[column].quantile(0.75),17.5))
        ax[i].axvline(dataframe[column].quantile(0.25), color='red', ls='--')
        ax[i].axvline(dataframe[column].quantile(0.75), color='green', ls='--')
    fig.tight_layout(pad=2.0)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
columns = ['sat_participation_2017', 'sat_participation_2018', 'act_participation_2017', 'act_participation_2018']
titles = ['SAT Participation Rate in 2017', 'SAT Participation Rate in 2018', 'ACT Participation Rate in 2017', 'ACT Participation Rate in 2018']
xlabels = ['Participation Rate, %']*4
subplot_histograms(final, columns, titles, xlabels)

# %% [markdown]
# As observed previously in the correlation heatmap, most states are either extremely inclined to SAT or ACT. However, there are a few states that have a more balanced demographics on the SAT vs ACT inclination.
#
# From the SAT distribution, we can see that there is certainly growth in the SAT participation rate from 2017 to 2018. The median has shifted from 38% up to 52%.
#
# However, ACT is still proved to be the more popular assessment in the United States, with its median close to 70%. More than 18% of the states in the US have a close-to 100% participation rate for ACT (as compared to only less than 10% observed in SAT). But the ACT has suffer a slight 3% dip in 2018, which may be caused by the rising popularity from SAT.

# %%
columns = ['sat_math_2017', 'sat_math_2018', 'act_math_2017', 'act_math_2017']
titles = ['SAT Math Score in 2017', 'SAT Math Score in 2018', 'ACT Math Score in 2017', 'ACT Math Score in 2018']
xlabels = ['Math Score']*4
subplot_histograms(final, columns, titles, xlabels)

# %% [markdown]
# It seems the math score distribution in ACT has almost remained unchanged from 2017 to 2018. While for the SAT, we may observed that the overall math score has slighted dropped from 2017 to 2018, which might be tied to the hike in SAT participation.

# %%
columns = ['sat_reading_writing_2017', 'sat_reading_writing_2018', 'act_reading_2017', 'act_reading_2018']
titles = ['SAT Reading & Writing Score in 2017', 'SAT Reading & Writing Score in 2018',
         'ACT Reading Score in 2017', 'ACT Reading Score in 2018']
xlabels = ['Reading & Writing Score']*2 + ['Reading Score']*2
subplot_histograms(final, columns, titles, xlabels)

# %% [markdown]
# Similar to math score, the reading and writing score of the SAT has suffered a slight drop from 2017 to 2018, and -once again, might be caused by hike in SAT popularity.
#
# There are negligible change from 2017 to 2018 in ACT.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def plot_scatter(x,y,title):
    # Plotting scatter point
    plt.figure(figsize=(8,6))
    plt.scatter(final[x], final[y])
    plt.title(title)
    plt.xlabel(x.replace('_',' ').title())
    plt.ylabel(y.replace('_',' ').title())
    
    # Plotting trend line
    z = np.polyfit(final[x], final[y], 1)
    p = np.poly1d(z)
    plt.plot([final[x].min(),final[x].max()],p([final[x].min(),final[x].max()]), 
             color='red', ls='dashed')
    
    # Displaying plot
    plt.show()

# %%
plot_scatter('sat_math_2017','act_math_2017','SAT vs ACT Math Score in 2017')

# %% [markdown]
# From the scatter plot, we may see that generally the ACT math score is negatively correlated to the SAT math score, however, the spread of the data is relatively large. So they are not strongly correlated.
#
# This is might be due to the different approaches or test structure in SAT and ACT, which render them not as comparable to each other.

# %%
plot_scatter('sat_reading_writing_2017','act_reading_2017','SAT vs ACT Reading Score in 2017')

# %% [markdown]
# Similar pattern is displayed at the reading or writing score for ACT and SAT. Generally negative-correlated, but very weak relationship.

# %%
plot_scatter('sat_total_2017','act_composite_2017','SAT vs ACT Total Score in 2017')

# %% [markdown]
# While the SAT total score and ACT composite score are collinear to its respectively subject score, it is not surprising that the scatter plot of SAT vs ACT total score exhibited the same pattern as above - negatively correlated but weak relationship.

# %%
plot_scatter('sat_total_2017','sat_total_2018','SAT Total Score in 2017 & 2018')

# %%
plot_scatter('act_composite_2017','act_composite_2018','ACT Composite Score in 2017 & 2018')

# %% [markdown]
# The 2 scatter plots on the 2017 and 2018 total/composite score of SAT and ACT has confirmed on our observation at the correlation heatmap. Generally speaking, most of the states maintain the same score over the one year period. However, there are a few states that has relatively great improvement or deterioration in the score. The phenomenon might be caused by the change in respective participation rate, which we will look in detail in the later part of the report.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Customized Box Plot Function
def plot_box(cols, xlabel, title):
    plt.figure(figsize=(8,8))
    temp_df = final[cols]
    sns.boxplot(y='variable', x='value', data=pd.melt(temp_df))
    plt.ylabel('')
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %%
# Participation Comparison
title = 'Comparison in Participation in 2017 and 2018'
plot_box(['sat_participation_2017','sat_participation_2018','act_participation_2017','act_participation_2018']
        , 'Participation Rate', title)

# %% [markdown]
# As shown in the boxplot above, both of the distribution range is about the same. However, SAT is skewed to right while ACT is skewed to left. That would mean that ACT have a relatively high participation rate among the U.S. states than SAT. The median and upper-quartile has rose in 2018 as compared to 2017, displaying its rise in popularity. On the other end, ACT has suffered a slight decrease in its median and lower-quartile, which likely was cannibalized by SAT.

# %%
# SAT subject comparison
title = 'SAT Subject Comparison'
columns = ['sat_math_2017', 'sat_math_2018', 'sat_reading_writing_2017', 'sat_reading_writing_2018',]
plot_box(columns, 'Score', title)

# %% [markdown]
# For the SAT subjects, both of them have very similar range and are positively skewed, with most of states scoring at the lower half of percentile. Both of math and reading and writing have suffered a slight drop in the median score, likely accounted by the rising participation rate in 2018.
#
# However, the spread of SAT math in 2018 has decreased slightly, with a more concentrated data.

# %%
# SAT total score comparison
title = 'SAT Total Scores Comparison'
columns = ['sat_total_2017', 'sat_total_2018']
plot_box(columns, 'Score', title)

# %% [markdown]
# Same as the observation for the SAT math score, the SAT total score has dipped slightly in 2018, however the spread has decreased, with its lower limit rose from 950 to about 975.

# %%
# ACT scores comparison
title = 'ACT Scores Comparison'
columns = ['act_math_2017', 'act_math_2018', 'act_reading_2017', 'act_reading_2018',
           'act_science_2017', 'act_science_2018', 'act_english_2017', 'act_english_2018',
           'act_composite_2017', 'act_composite_2018']
plot_box(columns, 'Score', title)

# %% [markdown]
# For the ACT, most of the subject scores have a limits from about 18 to 26, except for English. It seems to have a relatively large spread than the other subjects, having limits from 16 up to 26. All the subjects have a positively skewed distribution and all the median has dropped from 2017 to 2018. However, generally speaking, the distribution for ACT has remained almost unchanged as compared to SAT.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
participation_2017 = final[['state', 'sat_participation_2017', 'act_participation_2017']].sort_values('sat_participation_2017')
participation_2017 = participation_2017.set_index('state')
participation_2017.plot(kind='bar', stacked=True, figsize=(15,10))
plt.axhline(y=100, c='k', ls='--')
plt.show()

# %% [markdown]
# As shown above, generally a state would either be inclined to SAT or ACT. However, there are several states that have very high participation for both the assessment. More than half of the states have a combined participation rate of more than 100%. It means that it is common in most of the states for student to take both SAT and ACT, namely in Florida, Hawaii, North Carolina, South Carolina and West Virginia, which are mostly at the west coast.

# %%
final['act_sat_inclination_2017'] = (final['sat_participation_2017'] - final['act_participation_2017'])/100
final['act_sat_inclination_2018'] = (final['sat_participation_2018'] - final['act_participation_2018'])/100

# %%
def plot_scatter(x,y,c,title):
    # Plotting scatter point
    plt.figure(figsize=(8,9))
    plt.scatter(final[x], final[y], c=final[c], cmap=plt.cm.get_cmap('RdYlBu', 5), s=50, lw=0.5, edgecolor='k')
    plt.title(title)
    plt.xlabel(x.replace('_',' ').title())
    plt.ylabel(y.replace('_',' ').title())
    
    # Plotting trend line
    z = np.polyfit(final[x], final[y], 1)
    p = np.poly1d(z)
    plt.plot([final[x].min(),final[x].max()],p([final[x].min(),final[x].max()]), color='blue', ls='dashed')
    plt.colorbar(label=c.replace('_',' ').title(), orientation='horizontal', shrink=0.3,
                 pad=0.1)
    
    # Displaying plot
    plt.show()

# %%
plot_scatter('sat_participation_2017', 'sat_total_2017', 'act_sat_inclination_2017', 'SAT Participation vs Total Score in 2017')

# %%
plot_scatter('sat_participation_2018', 'sat_total_2018', 'act_sat_inclination_2018', 'SAT Participation vs Total Score in 2018')

# %% [markdown]
# As shown in the two figure above, once again, we show that the relationship between the score is inversely proportional to the participation rate. However, a color map is overlaid to show effect of ACT-vs-SAT inclination. If the points is on the red spectrum, it indicates the state is a ACT-dominated state. If it is blue, it is a SAT-dominated state. A relatively rare white-colored state would indicated a neutral state with a well-balanced SAT to ACT ratio.
#
# Interestingly, the states that scores the highest in the country are all ACT-dominated states. So we may speculate that these high-scorer are actually students that have taken both the assessment in the ACT-dominated states. They might have done this to improve their chances of getting admission into more prestigious colleges.
#
# Alternatively, in the SAT-dominated states, huge majority of the students would take the SAT by default, thus having a lower mean SAT score than the other states, as it represents the population better. However, the lower mean score is actually a 'truer' mean of the SAT score in the specific state.

# %%
final['sat_growth'] = final['sat_participation_2018'] - final['sat_participation_2017']
final['act_growth'] = final['act_participation_2018'] - final['act_participation_2017']

# %%
def plot_scatter_sat(x,y,c,title):
    # Datapoints for general trend line
    x_polyfit = []
    y_polyfit = []
    
    # Plotting scatter point
    plt.figure(figsize=(12,12))
    plt.scatter(final[x], final[y], c=final[c], cmap=plt.cm.get_cmap('RdYlBu', 5), s=50, lw=0.5, edgecolor='k')
    plt.title(title)
    plt.xlabel(x.replace('_',' ').title())
    plt.ylabel(y.replace('_',' ').title())
    
    # Displaying outlying state
    for state in final.state:
        x_out = final.loc[final.state==state,'sat_total_2017'].values
        y_out = final.loc[final.state==state,'sat_total_2018'].values
        if ((x_out>1050) & (y_out<1050)) | ((x_out<1025) & (y_out>1050)):
            plt.annotate(state.title(), (x_out+5,y_out+5))
        else:
            x_polyfit.append(x_out)
            y_polyfit.append(y_out)

    # Plotting general trend line excluding outliers
    x_polyfit = np.asarray(x_polyfit).reshape(-1)
    y_polyfit = np.asarray(y_polyfit).reshape(-1)
    z = np.polyfit(pd.Series(x_polyfit), pd.Series(y_polyfit), 1)
    p = np.poly1d(z)
    plt.plot([x_polyfit.min(),x_polyfit.max()],p([x_polyfit.min(),x_polyfit.max()]), color='blue', ls='dashed')
    plt.colorbar(label=c.replace('_',' ').title(), orientation='horizontal', shrink=0.3,
                 pad=0.1)
    
    # Displaying plot
    plt.show()

plot_scatter_sat('sat_total_2017', 'sat_total_2018', 'sat_growth', 'SAT Score 2017 vs 2018')

# %% [markdown]
# With continuation from the point above, the speculation can be again be bolstered by plotting a scatter graph on the SAT score of 2017 vs 2018. As shown above, we may see that generally the states adhere to the trend line of almost 1 to 1, which signifies zero change in the SAT score. It also shows that the difficulty of the test remain constant throughout the 2 years period, so it is comparable on each state performance.
#
# The colormap is now illustating the growth rate in the SAT participation in 2018 from 2017. We may observe that Colorado and Illinois - both having participation rate growth of more than 60 percents, suffered a huge dip in the state average score. While on the other side of the spectrum, Florida, with negative growth rate (exodus of SAT takers) has gained very significant improvement on its average score.
#
# This phenomenon has strongly supported the speculation whereby only the overachievers would take both SAT and ACT to improve their chance of getting into colleges. Thus, when the states of Illinois and Colorado undergo a hike in the participation rate, the general population of students actually brought the state SAT performance down to the actual mean (or in other words, 'truer' mean) performance.
#
# The effect is can be seen in Florida in the opposite direction, where majority of the student actually stopped taking SAT, leaving only the more intelectually-prowess student participating in SAT. And thus bringing the average state score from about 1000 to 1100.
#
# However, we may also notice that there is actual drop in performance in several states, such as Hawaii, West Virginia and Utah.

# %%
final.loc[final.state.isin(['Hawaii','West Virginia','Utah']), ['state','sat_participation_2017','sat_participation_2018']]
# Out:
#             state  sat_participation_2017  sat_participation_2018
# 11         Hawaii                      55                      56
# 44           Utah                       3                       4
# 48  West Virginia                      14                      28

# %% [markdown]
# From the table, we may find that West Virginia actually saw about 14% spike in their participation rate in 2018. That might be reason behind its drop in average SAT score. However, there is only marginal changes (~1%) in the states of Hawaii and Utah, but we have observed significant drop in the state average score.

# %%
def plot_scatter_act(x,y,c,title):
    # Datapoints for general trend line
    x_polyfit = []
    y_polyfit = []
    
    # Plotting scatter point
    plt.figure(figsize=(12,12))
    plt.scatter(final[x], final[y], c=final[c], cmap=plt.cm.get_cmap('RdYlBu', 5), s=50, lw=0.5, edgecolor='k')
    plt.title(title)
    plt.xlabel(x.replace('_',' ').title())
    plt.ylabel(y.replace('_',' ').title())
    
    # Displaying outlying state
    for state in final.state:
        x_out = final.loc[final.state==state,x].values
        y_out = final.loc[final.state==state,y].values
        if ((x_out>21) & (y_out<21)) | ((x_out<22) & (y_out>23)) | ((x_out<20) & (y_out>20.5)):
            plt.annotate(state.title(), (x_out+0.05,y_out+0.1))
        else:
            x_polyfit.append(x_out)
            y_polyfit.append(y_out)

    # Plotting general trend line excluding outliers
    x_polyfit = np.asarray(x_polyfit).reshape(-1)
    y_polyfit = np.asarray(y_polyfit).reshape(-1)
    z = np.polyfit(pd.Series(x_polyfit), pd.Series(y_polyfit), 1)
    p = np.poly1d(z)
    plt.plot([x_polyfit.min(),x_polyfit.max()],p([x_polyfit.min(),x_polyfit.max()]), color='blue', ls='dashed')
    plt.colorbar(label=c.replace('_',' ').title(), orientation='horizontal', shrink=0.3,
                 pad=0.1)
    
    # Displaying plot
    plt.show()

plot_scatter_act('act_composite_2017', 'act_composite_2018', 'act_growth', 'ACT Score 2017 vs 2018')

# %% [markdown]
# On the other hand, the trend is very clear for ACT composite score. Significant improvement in state-average ACT score can be observed in the states of Colorado and Illinois, both having massive exodus of students from ACT to SAT, leaving only the more inteclectually-superior student taking the ACT.
#
# While on the opposite end of the spectrum we may see that states having huge growth in their ACT participation rate (Nebraska and Ohio), suffered the most in the composite score performance.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## ACT vs. SAT Dorminant States Changes from 2017 to 2018

# %% [markdown]
# ![Alt Text](../img/Map_Change.gif)

# %% [markdown]
# As shown in the transition illustrated above, it is obvious that many states are currently shifting towards SAT from ACT. The greatest changes happened in Colorado and Illinois, which were both ACT-dominated states in 2017. Noticeable changes from ACT to SAT may also be seen in in relatively neutral state such as Idaho and Texas.
#
# The influx might be contributed by policy change by the local state government - or maybe by College Board who are managing the SAT. The changes can be observed even clearer in the figure below, which shows the growth rate in factor from 2017 to 2018.

# %% [markdown]
# ## Growth Rate in SAT Participation from 2017 to 2018

# %% [markdown]
# ![Choropleth Map of SAT vs ACT Preferences in the U.S.](../img/Growth_Rate.png "Choropleth Map of SAT vs ACT Preferences in the U.S.")

# %% [markdown]
# From the choropleth map above, the visualization is clearer on the change in policy that affected the SAT-ACT inclination. For example, it is obvious now that Colorado and Illinois must have undergone some sort of reform to have achieved this stark growth rate. And on the other side, Nebraska, Ohio and Florida are actually on a negative growth rate. This is likely due to policy change in these states as well that is favorable to ACT instead that cause the students to jump to ACT from SAT.
#
# The background and effect of these policy change will be discussed in later part on further research.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
# Generally speaking, for both SAT and ACT, the data has maintained almost the same distribution in 2017 and 2018. However, let's drill down into all the variables:
#
# 1. SAT Participation - It is a positively-skewed multimodal distribution, with 3 peaks at 0%, 65% and 100% participation rate. The median and upper quartile has rose in 2018, showing an increase in the SAT popularity in the United States.
#
#
# 2. ACT Participation - Contrary to SAT Participation, it is a negatively-skewed multimodal distribution, with peaks at 0%, 70% and 100%. The negative skewness has shown that ACT is still a more popular assessment than SAT. However, its median and lower quartile has seen decrement in 2018, which might be cause by cannibalization of SAT.
#
#
# 3. SAT Total Score - The total score is a postively-skewed distribution, the disribution has seen no significant change over the one-year. Its median has dipped slightly in 2018, which might be the effect of the spike in participation rate. However the spread has decreased in 2018, with its lower limit rose from 950 to about 975, which means the worse-performing states are getting better and performing closer to the national average.
#
#
# 4. ACT Composite Score - Is is a postively-skewed distribution as well. It has a limit of about 18 to 26 points, which has almost remained constant in both 2017 and 2018.
#
#
# 5. SAT Math Score - It is a positively-skewed distribution, with its limit at about 475 to 650 points. The median has dropped slightly in 2018, which might be accounted by the rise in participation rate. But the lower limit has moved slighly higher in 2018, the lower variance has shown that worse-performing states are improving in 2018.
#
#
# 6. SAT Reading & Writing Score - Almost the same as SAT math score, however, its limit has largely remained constant from 2017 to 2018.
#
#
# 7. ACT Math Score - Positively skewed distribution with its limit being almost the same as the rest of the subject. The distribution closely resembles the composite score.
#
#
# 8. ACT Reading Score - The distribution is very similar to composite score as well. However, it has a higher upper-quartile, which means it has a higher variance or larger spread than the composite score.
#
#
# 9. ACT Science Score - It has a positively skewed distribution. Among the subject score in ACT, the science score has the lowest spread.
#
#
# 10. ACT English Score - The english score has a positively-skewed distribution, same as the other subject. But it has the highest spread among the 4 subjects in ACT, varies from 16 to 26.

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# Answer: No, we do not observe a normal distribution in the data.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: None of the three variables have exhibited any normal distribution. Instead, they are all multimodal distribution. For instance, the participation rates for both SAT and ACT are both peaked at either very low or very high rates. Most of the states are inclined to either SAT or ACT and very few of the states have balanced inclination.
#
# While for the math and reading scores, there are usually three peaks, which are at the 25th, 50th and 75th percentile. The score is highly correlated to participation rate. So with states that have very low participation rate, the scores are comparatively very high and the trend is vice versa, resulting in the multimodal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: No, it does not make sense to conduct any statistical inference to the data that we have because the data actually represents the population that we want to study. So there is no sampling error in the analysis conducted.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# Answer: It is not appropriate to compare SAT math scores to ACT math scores as they have a relatively weak correlation. The assessment are structured differently between SAT and ACT, so a student with higher SAT math score is not necessarily better than those scoring lower ACT math score. In the states where SAT is mandatory, the participants are largely made up of non-college-bound students; but on the contrary, only the highly-motivated student will take both the ACT and SAT. So comparison on ACT and SAT math score on any specific state would not be valid unless both of the participation rates of ACT and SAT are 100%, which did not happen.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# Since the data that we have actually represents the population that we want to study, there is no hypothesis tests required.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
growing_states = final.loc[final.sat_growth>10, ['state','sat_growth','sat_total_2017','sat_total_2018']]
growing_states['sat_performance_difference'] = round((growing_states.sat_total_2018 - growing_states.sat_total_2017)*100 /  growing_states.sat_total_2017)
growing_states
# Out:
#             state  sat_growth  sat_total_2017  sat_total_2018  \
# 5        Colorado          89            1201            1025
# 13       Illinois          90            1115            1019
# 30     New Jersey          12            1056            1094
# 32       New York          12            1052            1068
# 39   Rhode Island          26            1062            1018
# 48  West Virginia          14            1086             999
#
#     sat_performance_difference
# 5                        -15.0
# 13                        -9.0
# 30                         4.0
# 32                         2.0
# 39                        -4.0
# 48                        -8.0

# %% [markdown]
# In 2017, Colorado [[Testive, 2017]](https://www.testive.com/colorado-sat-change-2017/) and Illinois [[Chalkbeat, 2018]](https://chalkbeat.org/posts/chicago/2018/07/27/act-protests-state-boards-embrace-of-rival-test-provider/) have announced their respecitive Department of Education have chosen The College Board, makers of the SAT, over the ACT testing company as the mandatory college-entrance exam for 2018 cohort. The drastic change can be observed causing the aftermath of hike in SAT participation rate in both Colorado and Illinois, at a staggering rise of 90%. However, with the rise of the participation rate, we may also observe that the SAT score has dropped significantly for both states.
#
# Prior to the policy change commencement in 2018, ACT was the default choices in Colorado and Illinois, students are not likely to take both the ACT and the SAT unless they know they will score well [[CollegeVine, 2017]](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/). So it appeared that only the highly-motivated student would signed up for SAT, thus bringing the SAT average score to the higher percentile. In 2018, when SAT became mandatory, the SAT average score can now be seen to truly represent the state average because all the students are taking the assessment. Hence, as expected, the SAT average score came down the true mean score of the graduate in the 2 states.
#
# Apart from that, in 2018, there are 10 states that participated in the SAT School Day Program, namely Colorado, Connecticut, Delaware, Idaho, Illinois, Maine, Michigan, New Hampshire, Rhode Island and West Virginia. Under this programme, students are allowed to take the SAT during regular school hours usually at no cost [[College Board, 2018]](https://www.collegeboard.org/releases/2018/more-than-2-million-students-in-class-of-2018-took-sat-highest-ever).

# %%
states = ['Colorado', 'Connecticut', 'Delaware', 'Idaho', 'Illinois', 'Maine', 'Michigan', 'New Hampshire', 
          'Rhode Island', 'West Virginia']
final.loc[final.state.isin(states), ['state','sat_participation_2017','sat_participation_2018','sat_growth',
                                     'sat_total_2017','sat_total_2018']].sort_values('sat_participation_2018')
# Out:
#             state  sat_participation_2017  sat_participation_2018  sat_growth  \
# 48  West Virginia                      14                      28          14
# 29  New Hampshire                      96                      96           0
# 39   Rhode Island                      71                      97          26
# 13       Illinois                       9                      99          90
# 19          Maine                      95                      99           4
# 5        Colorado                      11                     100          89
# 6     Connecticut                     100                     100           0
# 7        Delaware                     100                     100           0
# 12          Idaho                      93                     100           7
# 22       Michigan                     100                     100           0
#
#     sat_total_2017  sat_total_2018
# 48            1086             999
# 29            1052            1063
# ...

# %%
states = ['Colorado', 'Connecticut', 'Delaware', 'Idaho', 'Illinois', 'Maine', 'Michigan', 'New Hampshire', 
          'Rhode Island', 'West Virginia']
ten_states = final.loc[final.state.isin(states), ['state','sat_participation_2017','sat_participation_2018',
                                                  'sat_growth','sat_total_2017',
                                                  'sat_total_2018']].sort_values('sat_participation_2018')

plt.figure(figsize=(10,6))
for state in ten_states.state:
    y1 = ten_states.loc[ten_states.state==state, 'sat_participation_2017'].values
    y2 = ten_states.loc[ten_states.state==state, 'sat_participation_2018'].values
    plt.plot([2017,2018],[y1, y2], marker='o', label=state)
plt.xticks([2017,2018])
plt.title('10 States with SAT School Day Programme')
plt.ylabel('SAT Participation Rate, %')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# If we filter the data down to only the 10 states that offer the SAT School Day Program, it is easy to notice that all of the 10 states have more than 95% percent of participation rate, except for West Virginia. Great increment has been achieved in the participation rate in all the states that has not achieved 100% percent participation rate. Apart from Colorado and Illinois, where SAT was made mandatory, we may observe significant growth in states like West Virginia and Rhode Islands, at 14% and 26% growth respectively. This may well be a testament to show the effectiveness of the School Day Program.

# %%
final.loc[final.act_growth>5, ['state', 'act_participation_2017', 'act_participation_2018', 'act_growth',
                              'act_composite_2017','act_composite_2018']]
# Out:
#        state  act_participation_2017  act_participation_2018  act_growth  \
# 27  Nebraska                      84                     100          16
# 35      Ohio                      75                     100          25
#
#     act_composite_2017  act_composite_2018
# 27                21.4                20.1
# 35                22.0                20.3

# %% [markdown]
# Now, let's look from the ACT perspective to understand the initiatives carried out by the testing body to improve their participation rate. From the table above, apparently there are only 2 states that have significant growth in the ACT participation rate, namely Ohio and Nebraska.
#
# In Ohio, the Class of 2018 was the first class where the state government paid for all students to take the assessment [[Dayton Daily News, 2018]](https://www.daytondailynews.com/news/national-act-scores-for-class-2018-worst-decades-officials-say/EKA05C3FHcjN4bx8BmcC2N/). It would mean that thousands of largely non-college-bound students who were not tested in the past were tested in 2018. That sent Ohio’s participation rate from 75 percent to 100 percent, but dipped Ohio’s average composite score from 22.0 to 20.3.
#
# Same thing is happening in Nebraska when the state government started offering the ACT assessment for free to all juniors in 2017 [[Nebraska Department of Education, 2019]](https://www.education.ne.gov/press_release/nebraska-students-continue-to-out-perform-peer-states-on-act/). The trend continues in 2018 where the participation rate has grown 16% to a full 100% participation rate.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
final.loc[final.act_sat_inclination_2018.between(-0.4,0),['state','act_sat_inclination_2018','sat_participation_2017',
                                            'sat_participation_2018']].sort_values('sat_participation_2018')
# Out:
#             state  act_sat_inclination_2018  sat_participation_2017  \
# 48  West Virginia                     -0.37                      14
# 2         Arizona                     -0.37                      30
# 9         Florida                     -0.10                      83
# 11         Hawaii                     -0.33                      55
#
#     sat_participation_2018
# 48                      28
# 2                       29
# 9                       56
# 11                      56

# %% [markdown]
# If we look into states where it is not 'monopolized' by ACT, as shown in the table above, these are states that has lower SAT participation rate but still relatively neutral on its stance (or rather, policy) on ACT vs SAT. These states would be easier to be converted than others, none of these 4 states have policy that is favourable towards ACT [[PrepScholar, 2019]](https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice). So if we would to only target at a single state to promote SAT, West Virginia would be the best candidate.

# %% [markdown]
# West Virginia has already gained momentum from the SAT School Day Programme that allows student to participate in the assessment for free and during a school day (instead of Weekends). The most cost-effective method to improve the SAT participation rate in West Virginia would be to organize state-wide campaign promoting the School Day Programme, so we may fully utilize the momentum we have created by investing in the programme. The participation would certainly be improved when the high school juniors are more well-informed of the programme that comes at zero cost and held on an usual school day.
#
# However, once the effect of the School Day Programme has plateaued, the College Board may look into options to negotiate with the state government for long term support and contract to make SAT mandatory state-wide. This method would have a higher cost impact, but considering West Virginia has a relatively low population count (39th place out of 50 states in U.S.), the cost would be relatively lower than most of the states (such as Illinois or Colorado) that has implemented such contract.
